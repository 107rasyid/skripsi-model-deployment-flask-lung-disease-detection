# %% [markdown]
# # **Inisisialisasi Konfigurasi Pelatihan**

# %%
class cfg:
    IMAGE_SIZE = 256
    # Data Augmentasi
    BRIGHTNESS = (0.64, 1.37)
    CONTRAST = (0.64, 1.37)
    # Pelatihan Model
    AUGMENTED = True
    DROPOUT = 0.5
    BATCH_SIZE = 8
    EPOCHS = 150
    LEARNING_RATE = 0.0001

# %% [markdown]
# # **Inisialisasi Library yang Digunakan**

# %%
# Library Machine Learning dan Deep Learning
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.utils import plot_model
from sklearn.utils import shuffle
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Model

# Library Pengolahan Data dan File
import numpy as np
import pandas as pd
from PIL import Image, ImageEnhance
import cv2
import imgaug as ia
from imgaug import augmenters as iaa

# Library Visualisasi
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# Library Lain-Lain
import random
import os
import time
import json

# %% [markdown]
# # **Setting Environment Notebook**

# %%
# Mematikan Peringatan Tensorflow
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Mengatur seed
tf.random.set_seed(100)
np.random.seed(100)

# %%
# Mengaktifkan Presisi Campuran Float16
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %% [markdown]
# # **Inisialisasi Data Direktori dan Membuat Dataframe**

# %%
# Direktori Data
data_directories = [
    '/kaggle/input/dataset-klasifikasi-v5/COVID19',
    '/kaggle/input/dataset-klasifikasi-v5/NORMAL',
    '/kaggle/input/dataset-klasifikasi-v5/PNEUMONIA',
    '/kaggle/input/dataset-klasifikasi-v5/TUBERCULOSIS',
]

all_paths = []
all_labels = []

# Melakukan iterasi melalui setiap direktori
for data_dir in data_directories:
    if not os.path.exists(data_dir):  # Skip jika direktori tidak ada
        print(f"Directory {data_dir} does not exist. Skipping.")
        continue
    
    # Mengambil semua file dalam direktori
    for image in os.listdir(data_dir):
        # Memastikan file adalah citra
        if image.lower().endswith(('.jpg', '.jpeg', '.png')):
            all_paths.append(os.path.join(data_dir, image)) 
            # Menambahkan label dari nama folder
            label = os.path.basename(os.path.normpath(data_dir))
            all_labels.append(label)

# Mengacak Data
all_paths, all_labels = shuffle(all_paths, all_labels)

# Menampilkan sebagai DataFrame
pd.set_option('display.max_colwidth', None)
df = pd.DataFrame({'path': all_paths, 'label': all_labels})

print(df)
# Out:
#                                                                                   path  \
# 0                    /kaggle/input/dataset-klasifikasi-v5/COVID19/seg_COVID19(521).jpg
# 1                    /kaggle/input/dataset-klasifikasi-v5/COVID19/seg_COVID19(123).jpg
# 2      /kaggle/input/dataset-klasifikasi-v5/PNEUMONIA/seg_person658_bacteria_2550.jpeg
# 3           /kaggle/input/dataset-klasifikasi-v5/TUBERCULOSIS/seg_Tuberculosis-366.png
# 4            /kaggle/input/dataset-klasifikasi-v5/NORMAL/seg_NORMAL2-IM-0386-0001.jpeg
# ...                                                                                ...
# 4862  /kaggle/input/dataset-klasifikasi-v5/PNEUMONIA/seg_person1830_bacteria_4693.jpeg
# 4863         /kaggle/input/dataset-klasifikasi-v5/NORMAL/seg_NORMAL2-IM-0450-0001.jpeg
# 4864                  /kaggle/input/dataset-klasifikasi-v5/COVID19/seg_COVID19(71).jpg
# 4865                 /kaggle/input/dataset-klasifikasi-v5/COVID19/seg_COVID19(512).jpg
# 4866   /kaggle/input/dataset-klasifikasi-v5/PNEUMONIA/seg_person917_bacteria_2842.jpeg
#
#              label
# 0          COVID19
# 1          COVID19
# 2        PNEUMONIA
# 3     TUBERCULOSIS
# 4           NORMAL
# ...            ...
# 4862     PNEUMONIA
# 4863        NORMAL
# 4864       COVID19
# 4865       COVID19
# 4866     PNEUMONIA
#
# [4867 rows x 2 columns]

# %% [markdown]
# # **Membuat Fungsi Augmentasi dan Membaca Citra**

# %%
# Fungsi Augmentasi
def augment_image(image):
    image = Image.fromarray(np.uint8(image))
    brightness_factor = random.uniform(cfg.BRIGHTNESS[0], cfg.BRIGHTNESS[1])
    contrast_factor = random.uniform(cfg.CONTRAST[0], cfg.CONTRAST[1])
    image = ImageEnhance.Brightness(image).enhance(brightness_factor)
    image = ImageEnhance.Contrast(image).enhance(contrast_factor)
    return image

# %%
# Fungsi Untuk Membuka dan Memproses Gambar
def open_images(paths, augment=True):
    images = []
    for path in paths:
        image = load_img(path, target_size=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE))
        if augment:
            image = augment_image(image)
        image = np.array(image)
        image = image / image.max()
        images.append(image)
    return np.array(images)

# %%
# Visualisasi Beberapa Citra dengan Augmentasi
k = random.randint(0, 5000)
image_paths = list(df.path[k:k + 10])
labels = list(df.label[k:k + 10])
images = open_images(image_paths, augment=True)

plt.rcParams.update({'font.size': 10})
fig = plt.figure(figsize=(20, 8))
for i in range(0, 10):
    fig.add_subplot(2, 5, i + 1)
    plt .imshow(images[i])
    plt.axis('off')
    plt.title(labels[i])
plt.show()

# %% [markdown]
# # **Setting Label Encoder-Decoder**

# %%
# Daftar Label dan Pengkodeannya
LABELS = ['NORMAL', 'TUBERCULOSIS', 'PNEUMONIA', 'COVID19']
label_encoder = {'NORMAL': 0, 'TUBERCULOSIS': 1, 'PNEUMONIA': 2, 'COVID19': 3}
label_decoder = {0: 'NORMAL', 1: 'TUBERCULOSIS', 2: 'PNEUMONIA', 3: 'COVID19'}

# %% [markdown]
# # **Pembagian Data**

# %%
# Menentukan Persentase Pembagian Data
train_split = 0.8
val_split = 0.1
test_split = 0.1

# Memastikan total persentase sesuai dengan 100%
assert train_split + val_split + test_split == 1.0, "Total split harus 1.0"

# Menghitung indeks pemisahan
train_end = int(train_split * len(df))
val_end = train_end + int(val_split * len(df))

# Melakukan pemisahan dataset
df_train = df[:train_end]
df_val = df[train_end:val_end]
df_test = df[val_end:]

print(f"Train set: {len(df_train)} samples")
print(f"Validation set: {len(df_val)} samples")
print(f"Test set: {len(df_test)} samples")
# Out:
# Train set: 3893 samples
# Validation set: 486 samples
# Test set: 488 samples

# %% [markdown]
# # **Membuat Data Generator**

# %%
# Generator data untuk train, val, dan test
def data_generator(df, batch_size=cfg.BATCH_SIZE, augment=False, epochs=cfg.EPOCHS):
    for e in range(epochs):
        for x in range(0, len(df), batch_size):
            image_paths = df.path[x:x + batch_size]
            images = open_images(image_paths, augment=augment)
            labels = df.label[x:x + batch_size]
            labels = [label_encoder[label] for label in labels]
            yield images, np.array(labels)

# Generator masing-masing set
train_data_generator = data_generator(df_train, batch_size=cfg.BATCH_SIZE, augment=cfg.AUGMENTED)
val_data_generator = data_generator(df_val, batch_size=cfg.BATCH_SIZE)
test_data_generator = data_generator(df_test, batch_size=cfg.BATCH_SIZE)

train_steps = int(len(df_train) / cfg.BATCH_SIZE)
val_steps = int(len(df_val) / cfg.BATCH_SIZE)
test_steps = int(len(df_test) / cfg.BATCH_SIZE)

# %% [markdown]
# # **Visualisasi Pembagian Data**

# %%
# Distribusi label pada setiap subset
train_counts = df_train['label'].value_counts()
val_counts = df_val['label'].value_counts()
test_counts = df_test['label'].value_counts()

# Visualisasi distribusi
plt.figure(figsize=(12, 6))

# Plot untuk setiap subset
x = np.arange(len(LABELS))
width = 0.25

plt.bar(x - width, train_counts.reindex(LABELS, fill_value=0), width, label='Data Latih', color='#43b0c1')
plt.bar(x, val_counts.reindex(LABELS, fill_value=0), width, label='Data Validasi', color='#368d9a')
plt.bar(x + width, test_counts.reindex(LABELS, fill_value=0), width, label='Data Uji', color='#2a6e88')

for i, v in enumerate(train_counts.reindex(LABELS, fill_value=0)):
    plt.text(i - width, v + 1, str(v), color='black', ha='center')

for i, v in enumerate(val_counts.reindex(LABELS, fill_value=0)):
    plt.text(i, v + 1, str(v), color='black', ha='center')

for i, v in enumerate(test_counts.reindex(LABELS, fill_value=0)):
    plt.text(i + width, v + 1, str(v), color='black', ha='center')

plt.xlabel('Label')
plt.ylabel('Jumlah')
plt.title('Distribusi Label untuk Data Latih, Validasi, dan Uji')
plt.xticks(x, LABELS)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Membuat Model**

# %%
'''
# Model CNN
# Input layer
input_layer = Input(shape=(256, 256, 3))

# Conv2D layers with MaxPooling2D and Dropout
x = Conv2D(16, (3, 3), activation='relu')(input_layer)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(256, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)

# Dropout layer
x = Dropout(cfg.DROPOUT)(x)

# Flatten and Dense layers
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
output_layer = Dense(4, activation='softmax')(x)

# Define model
model = Model(inputs=input_layer, outputs=output_layer)

# Print model summary
model.summary()
'''
# Out:
# "\n# Model CNN\n# Input layer\ninput_layer = Input(shape=(256, 256, 3))\n\n# Conv2D layers with MaxPooling2D and Dropout\nx = Conv2D(16, (3, 3), activation='relu')(input_layer)\nx = MaxPooling2D((2, 2))(x)\nx = Conv2D(32, (3, 3), activation='relu')(x)\nx = MaxPooling2D((2, 2))(x)\nx = Conv2D(64, (3, 3), activation='relu')(x)\nx = MaxPooling2D((2, 2))(x)\nx = Conv2D(128, (3, 3), activation='relu')(x)\nx = MaxPooling2D((2, 2))(x)\nx = Conv2D(256, (3, 3), activation='relu')(x)\nx = MaxPooling2D((2, 2))(x)\n\n# Dropout layer\nx = Dropout(cfg.DROPOUT)(x)\n\n# Flatten and Dense layers\nx = Flatten()(x)\nx = Dense(256, activation='relu')(x)\noutput_layer = Dense(4, activation='softmax')(x)\n\n# Define model\nmodel = Model(inputs=input_layer, outputs=output_layer)\n\n# Print model summary\nmodel.summary()\n"

# %%
'''
# MobileNetV2
base_model = tf.keras.applications.MobileNetV2(input_shape=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE, 3),
                                               include_top=False,
                                               weights='imagenet')

# Bekukan model dasar untuk mencegah perubahan saat pelatihan
base_model.trainable = False

# Buat model menggunakan Functional API
inputs = layers.Input(shape=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE, 3))
x = base_model(inputs, training=False) 
x = layers.GlobalAveragePooling2D(name='global_avg_pool')(x)
x = layers.Dense(256, activation='relu', name='dense1')(x)
outputs = layers.Dense(4, activation='softmax', name='final')(x)

# Buat model dengan nama 'MobileNetV2_classifier'
model = models.Model(inputs=inputs, outputs=outputs, name='MobileNetV2_classifier')

# Tampilkan ringkasan model
model.summary()
'''
# Out:
# "\n# MobileNetV2\nbase_model = tf.keras.applications.MobileNetV2(input_shape=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE, 3),\n                                               include_top=False,\n                                               weights='imagenet')\n\n# Bekukan model dasar untuk mencegah perubahan saat pelatihan\nbase_model.trainable = False\n\n# Buat model menggunakan Functional API\ninputs = layers.Input(shape=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE, 3))\nx = base_model(inputs, training=False) \nx = layers.GlobalAveragePooling2D(name='global_avg_pool')(x)\nx = layers.Dense(256, activation='relu', name='dense1')(x)\noutputs = layers.Dense(4, activation='softmax', name='final')(x)\n\n# Buat model dengan nama 'MobileNetV2_classifier'\nmodel = models.Model(inputs=inputs, outputs=outputs, name='MobileNetV2_classifier')\n\n# Tampilkan ringkasan model\nmodel.summary()\n"

# %%
# VGG19
base_model = tf.keras.applications.VGG19(input_shape=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE, 3),
                                               include_top=False,
                                               weights='imagenet')
base_model.trainable = False

inputs = layers.Input(shape=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE, 3))
x = base_model(inputs, training=False) 
x = layers.GlobalAveragePooling2D(name='global_avg_pool')(x)
x = layers.Dense(256, activation='relu', name='dense1')(x)
outputs = layers.Dense(4, activation='softmax', name='final')(x)

model = models.Model(inputs=inputs, outputs=outputs, name='VGG19_classifier')
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "VGG19_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 256, 256, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ vgg19 (Functional)                   │ (None, 8, 8, 512)           │      20,024,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_avg_pool                      │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense1 (Dense)                       │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ final (Dense)                        │ (None, 4)                   │           1,028 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,156,740 (76.89 MB)
#  Trainable params: 132,356 (517.02 KB)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
'''# Xception
base_model = tf.keras.applications.Xception(input_shape=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE, 3),
                                                  include_top=False,
                                                  weights='imagenet')
base_model.trainable = False

inputs = layers.Input(shape=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE, 3))
x = base_model(inputs, training=False) 
x = layers.GlobalAveragePooling2D(name='global_avg_pool')(x)
x = layers.Dropout(0.3, name='dropout1')(x)
x = layers.Dense(256, activation='relu', name='dense1')(x)
outputs = layers.Dense(4, activation='softmax', name='final')(x)

model = models.Model(inputs=inputs, outputs=outputs, name='Xception_classifier')
model.summary()
'''
# Out:
# "# Xception\nbase_model = tf.keras.applications.Xception(input_shape=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE, 3),\n                                                  include_top=False,\n                                                  weights='imagenet')\nbase_model.trainable = False\n\ninputs = layers.Input(shape=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE, 3))\nx = base_model(inputs, training=False) \nx = layers.GlobalAveragePooling2D(name='global_avg_pool')(x)\nx = layers.Dropout(0.3, name='dropout1')(x)\nx = layers.Dense(256, activation='relu', name='dense1')(x)\noutputs = layers.Dense(4, activation='softmax', name='final')(x)\n\nmodel = models.Model(inputs=inputs, outputs=outputs, name='Xception_classifier')\nmodel.summary()\n"

# %%
'''
# DenseNet201
base_model = tf.keras.applications.DenseNet201(input_shape=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE, 3),
                                                     include_top=False,
                                                     weights='imagenet')
base_model.trainable = False

inputs = layers.Input(shape=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE, 3))
x = base_model(inputs, training=False) 
x = layers.GlobalAveragePooling2D(name='global_avg_pool')(x)
x = layers.Dense(256, activation='relu', name='dense1')(x)
outputs = layers.Dense(4, activation='softmax', name='final')(x)

model = models.Model(inputs=inputs, outputs=outputs, name='DenseNet201_classifier')
model.summary()
'''
# Out:
# "\n# DenseNet201\nbase_model = tf.keras.applications.DenseNet201(input_shape=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE, 3),\n                                                     include_top=False,\n                                                     weights='imagenet')\nbase_model.trainable = False\n\ninputs = layers.Input(shape=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE, 3))\nx = base_model(inputs, training=False) \nx = layers.GlobalAveragePooling2D(name='global_avg_pool')(x)\nx = layers.Dense(256, activation='relu', name='dense1')(x)\noutputs = layers.Dense(4, activation='softmax', name='final')(x)\n\nmodel = models.Model(inputs=inputs, outputs=outputs, name='DenseNet201_classifier')\nmodel.summary()\n"

# %% [markdown]
# # **Kompilasi Model**

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=cfg.LEARNING_RATE),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # **Mengatur Kelas Weight**

# %%
class_weights = (df_train.label.value_counts() / len(df_train)).to_dict()
class_weights = dict((label_encoder[key], value) for (key, value) in class_weights.items())
class_weights
# Out:
# {2: 0.4130490624197277,
#  0: 0.32545594657076804,
#  1: 0.14025173388132545,
#  3: 0.12124325712817878}

# %% [markdown]
# # **Membuat Fungsi Callback yang Digunakan Selama Pelatihan**

# %%
# Callback untuk menyimpan history training ke file JSON
class SaveHistoryCallback(Callback):
    def __init__(self, file_path):
        super().__init__()
        self.file_path = file_path

    def on_train_end(self, logs=None):
        with open(self.file_path, 'w') as f:
            json.dump(self.model.history.history, f)

# Callback untuk menghitung waktu pelatihan
class TrainingTimeCallback(Callback):
    def on_train_begin(self, logs=None):
        self.start_time = time.time()

    def on_train_end(self, logs=None):
        elapsed_time = time.time() - self.start_time
        print(f"Total training time: {elapsed_time:.2f} seconds")

# Callback untuk memplot metrik
class MetricsCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        val_metrics = {k: logs[k] for k in logs if 'val_' in k}
        print(f"Epoch {epoch + 1}: Validation Metrics: {val_metrics}")


# Definisi callback yang disediakan Keras
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
checkpoint = ModelCheckpoint(
    filepath='best_model.keras',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    mode='min',
    verbose=1
)

# Definisi callback custom
history_callback = SaveHistoryCallback(file_path='training_history.json')
training_time_callback = TrainingTimeCallback()

# Gabungkan semua callback
callbacks_list = [
    early_stopping,
    reduce_lr,
    checkpoint,
    history_callback,
    training_time_callback,
    MetricsCallback()
]

# %% [markdown]
# # **Pelatihan Model**

# %%
history = model.fit(train_data_generator,
                    epochs=cfg.EPOCHS,
                    steps_per_epoch=train_steps,
                    validation_data=val_data_generator,
                    validation_steps=val_steps,
                    callbacks=callbacks_list)
# Out:
# Epoch 1/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.5735 - loss: 1.1448
# Epoch 1: val_loss improved from inf to 0.83848, saving model to best_model.keras
# Epoch 1: Validation Metrics: {'val_accuracy': 0.7729166746139526, 'val_loss': 0.8384793400764465}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 67s 120ms/step - accuracy: 0.5736 - loss: 1.1446 - val_accuracy: 0.7729 - val_loss: 0.8385 - learning_rate: 1.0000e-04
# Epoch 2/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7613 - loss: 0.7989
# Epoch 2: val_loss improved from 0.83848 to 0.63333, saving model to best_model.keras
# Epoch 2: Validation Metrics: {'val_accuracy': 0.7949790954589844, 'val_loss': 0.633331835269928}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - accuracy: 0.7613 - loss: 0.7987 - val_accuracy: 0.7950 - val_loss: 0.6333 - learning_rate: 1.0000e-04
# Epoch 3/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8038 - loss: 0.6124
# Epoch 3: val_loss improved from 0.63333 to 0.51714, saving model to best_model.keras
# Epoch 3: Validation Metrics: {'val_accuracy': 0.8305439352989197, 'val_loss': 0.5171391367912292}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.8038 - loss: 0.6123 - val_accuracy: 0.8305 - val_loss: 0.5171 - learning_rate: 1.0000e-04
# Epoch 4/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8425 - loss: 0.5046
# Epoch 4: val_loss improved from 0.51714 to 0.44854, saving model to best_model.keras
# Epoch 4: Validation Metrics: {'val_accuracy': 0.8430962562561035, 'val_loss': 0.44854024052619934}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.8425 - loss: 0.5046 - val_accuracy: 0.8431 - val_loss: 0.4485 - learning_rate: 1.0000e-04
# Epoch 5/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8608 - loss: 0.4370
# Epoch 5: val_loss improved from 0.44854 to 0.40725, saving model to best_model.keras
# Epoch 5: Validation Metrics: {'val_accuracy': 0.8451882600784302, 'val_loss': 0.4072543680667877}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.8607 - loss: 0.4370 - val_accuracy: 0.8452 - val_loss: 0.4073 - learning_rate: 1.0000e-04
# Epoch 6/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8733 - loss: 0.3939
# Epoch 6: val_loss improved from 0.40725 to 0.38004, saving model to best_model.keras
# Epoch 6: Validation Metrics: {'val_accuracy': 0.8535565137863159, 'val_loss': 0.3800407648086548}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.8733 - loss: 0.3939 - val_accuracy: 0.8536 - val_loss: 0.3800 - learning_rate: 1.0000e-04
# Epoch 7/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8738 - loss: 0.3700
# Epoch 7: val_loss improved from 0.38004 to 0.35669, saving model to best_model.keras
# Epoch 7: Validation Metrics: {'val_accuracy': 0.8598326444625854, 'val_loss': 0.3566886782646179}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.8738 - loss: 0.3700 - val_accuracy: 0.8598 - val_loss: 0.3567 - learning_rate: 1.0000e-04
# Epoch 8/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8831 - loss: 0.3492
# Epoch 8: val_loss improved from 0.35669 to 0.34284, saving model to best_model.keras
# Epoch 8: Validation Metrics: {'val_accuracy': 0.874476969242096, 'val_loss': 0.3428439795970917}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.8831 - loss: 0.3492 - val_accuracy: 0.8745 - val_loss: 0.3428 - learning_rate: 1.0000e-04
# Epoch 9/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8862 - loss: 0.3254
# Epoch 9: val_loss improved from 0.34284 to 0.32591, saving model to best_model.keras
# Epoch 9: Validation Metrics: {'val_accuracy': 0.8807531595230103, 'val_loss': 0.32590851187705994}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.8862 - loss: 0.3254 - val_accuracy: 0.8808 - val_loss: 0.3259 - learning_rate: 1.0000e-04
# Epoch 10/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8853 - loss: 0.3194
# Epoch 10: val_loss improved from 0.32591 to 0.31592, saving model to best_model.keras
# Epoch 10: Validation Metrics: {'val_accuracy': 0.8849372267723083, 'val_loss': 0.31592246890068054}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.8852 - loss: 0.3194 - val_accuracy: 0.8849 - val_loss: 0.3159 - learning_rate: 1.0000e-04
# Epoch 11/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8923 - loss: 0.3026
# Epoch 11: val_loss improved from 0.31592 to 0.30180, saving model to best_model.keras
# Epoch 11: Validation Metrics: {'val_accuracy': 0.8912134170532227, 'val_loss': 0.3017950654029846}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.8923 - loss: 0.3027 - val_accuracy: 0.8912 - val_loss: 0.3018 - learning_rate: 1.0000e-04
# Epoch 12/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8930 - loss: 0.2883
# Epoch 12: val_loss improved from 0.30180 to 0.28924, saving model to best_model.keras
# Epoch 12: Validation Metrics: {'val_accuracy': 0.8933054208755493, 'val_loss': 0.2892426550388336}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.8930 - loss: 0.2883 - val_accuracy: 0.8933 - val_loss: 0.2892 - learning_rate: 1.0000e-04
# Epoch 13/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8940 - loss: 0.2854
# Epoch 13: val_loss improved from 0.28924 to 0.27785, saving model to best_model.keras
# Epoch 13: Validation Metrics: {'val_accuracy': 0.8953974843025208, 'val_loss': 0.2778541147708893}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.8940 - loss: 0.2854 - val_accuracy: 0.8954 - val_loss: 0.2779 - learning_rate: 1.0000e-04
# Epoch 14/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8992 - loss: 0.2803
# Epoch 14: val_loss improved from 0.27785 to 0.27553, saving model to best_model.keras
# Epoch 14: Validation Metrics: {'val_accuracy': 0.8953974843025208, 'val_loss': 0.2755303978919983}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.8992 - loss: 0.2803 - val_accuracy: 0.8954 - val_loss: 0.2755 - learning_rate: 1.0000e-04
# Epoch 15/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9013 - loss: 0.2701
# Epoch 15: val_loss improved from 0.27553 to 0.26692, saving model to best_model.keras
# Epoch 15: Validation Metrics: {'val_accuracy': 0.9037656784057617, 'val_loss': 0.26691845059394836}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9013 - loss: 0.2702 - val_accuracy: 0.9038 - val_loss: 0.2669 - learning_rate: 1.0000e-04
# Epoch 16/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9044 - loss: 0.2642
# Epoch 16: val_loss improved from 0.26692 to 0.26305, saving model to best_model.keras
# Epoch 16: Validation Metrics: {'val_accuracy': 0.8995816111564636, 'val_loss': 0.26304930448532104}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9044 - loss: 0.2642 - val_accuracy: 0.8996 - val_loss: 0.2630 - learning_rate: 1.0000e-04
# Epoch 17/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9027 - loss: 0.2640
# Epoch 17: val_loss improved from 0.26305 to 0.26020, saving model to best_model.keras
# Epoch 17: Validation Metrics: {'val_accuracy': 0.9016736149787903, 'val_loss': 0.2602006196975708}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9027 - loss: 0.2640 - val_accuracy: 0.9017 - val_loss: 0.2602 - learning_rate: 1.0000e-04
# Epoch 18/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9041 - loss: 0.2539
# Epoch 18: val_loss improved from 0.26020 to 0.25252, saving model to best_model.keras
# Epoch 18: Validation Metrics: {'val_accuracy': 0.9058577418327332, 'val_loss': 0.252517968416214}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9041 - loss: 0.2539 - val_accuracy: 0.9059 - val_loss: 0.2525 - learning_rate: 1.0000e-04
# Epoch 19/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9065 - loss: 0.2509
# Epoch 19: val_loss improved from 0.25252 to 0.24108, saving model to best_model.keras
# Epoch 19: Validation Metrics: {'val_accuracy': 0.910041868686676, 'val_loss': 0.24108050763607025}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9065 - loss: 0.2509 - val_accuracy: 0.9100 - val_loss: 0.2411 - learning_rate: 1.0000e-04
# Epoch 20/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9081 - loss: 0.2525
# Epoch 20: val_loss improved from 0.24108 to 0.24106, saving model to best_model.keras
# Epoch 20: Validation Metrics: {'val_accuracy': 0.9058577418327332, 'val_loss': 0.24105773866176605}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9081 - loss: 0.2525 - val_accuracy: 0.9059 - val_loss: 0.2411 - learning_rate: 1.0000e-04
# Epoch 21/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9049 - loss: 0.2450
# Epoch 21: val_loss improved from 0.24106 to 0.23210, saving model to best_model.keras
# Epoch 21: Validation Metrics: {'val_accuracy': 0.9037656784057617, 'val_loss': 0.2320983111858368}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9049 - loss: 0.2450 - val_accuracy: 0.9038 - val_loss: 0.2321 - learning_rate: 1.0000e-04
# Epoch 22/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9101 - loss: 0.2400
# Epoch 22: val_loss improved from 0.23210 to 0.23004, saving model to best_model.keras
# Epoch 22: Validation Metrics: {'val_accuracy': 0.9058577418327332, 'val_loss': 0.23004315793514252}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9101 - loss: 0.2400 - val_accuracy: 0.9059 - val_loss: 0.2300 - learning_rate: 1.0000e-04
# Epoch 23/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9139 - loss: 0.2333
# Epoch 23: val_loss improved from 0.23004 to 0.22327, saving model to best_model.keras
# Epoch 23: Validation Metrics: {'val_accuracy': 0.910041868686676, 'val_loss': 0.22327399253845215}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9139 - loss: 0.2333 - val_accuracy: 0.9100 - val_loss: 0.2233 - learning_rate: 1.0000e-04
# Epoch 24/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9166 - loss: 0.2299
# Epoch 24: val_loss improved from 0.22327 to 0.21518, saving model to best_model.keras
# Epoch 24: Validation Metrics: {'val_accuracy': 0.9163179993629456, 'val_loss': 0.2151796817779541}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 46ms/step - accuracy: 0.9167 - loss: 0.2299 - val_accuracy: 0.9163 - val_loss: 0.2152 - learning_rate: 1.0000e-04
# Epoch 25/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9176 - loss: 0.2275
# Epoch 25: val_loss did not improve from 0.21518
# Epoch 25: Validation Metrics: {'val_accuracy': 0.9142259359359741, 'val_loss': 0.2180997133255005}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9176 - loss: 0.2274 - val_accuracy: 0.9142 - val_loss: 0.2181 - learning_rate: 1.0000e-04
# Epoch 26/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9179 - loss: 0.2270
# Epoch 26: val_loss improved from 0.21518 to 0.20696, saving model to best_model.keras
# Epoch 26: Validation Metrics: {'val_accuracy': 0.9142259359359741, 'val_loss': 0.2069646716117859}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9179 - loss: 0.2270 - val_accuracy: 0.9142 - val_loss: 0.2070 - learning_rate: 1.0000e-04
# Epoch 27/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9165 - loss: 0.2213
# Epoch 27: val_loss did not improve from 0.20696
# Epoch 27: Validation Metrics: {'val_accuracy': 0.9142259359359741, 'val_loss': 0.2090366631746292}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9165 - loss: 0.2213 - val_accuracy: 0.9142 - val_loss: 0.2090 - learning_rate: 1.0000e-04
# Epoch 28/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9194 - loss: 0.2199
# Epoch 28: val_loss improved from 0.20696 to 0.20420, saving model to best_model.keras
# Epoch 28: Validation Metrics: {'val_accuracy': 0.9205020666122437, 'val_loss': 0.2042001187801361}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9194 - loss: 0.2199 - val_accuracy: 0.9205 - val_loss: 0.2042 - learning_rate: 1.0000e-04
# Epoch 29/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9208 - loss: 0.2143
# Epoch 29: val_loss improved from 0.20420 to 0.20358, saving model to best_model.keras
# Epoch 29: Validation Metrics: {'val_accuracy': 0.918410062789917, 'val_loss': 0.2035815417766571}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9208 - loss: 0.2143 - val_accuracy: 0.9184 - val_loss: 0.2036 - learning_rate: 1.0000e-04
# Epoch 30/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9266 - loss: 0.2085
# Epoch 30: val_loss improved from 0.20358 to 0.20082, saving model to best_model.keras
# Epoch 30: Validation Metrics: {'val_accuracy': 0.9205020666122437, 'val_loss': 0.200815349817276}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9266 - loss: 0.2085 - val_accuracy: 0.9205 - val_loss: 0.2008 - learning_rate: 1.0000e-04
# Epoch 31/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9251 - loss: 0.2049
# Epoch 31: val_loss improved from 0.20082 to 0.19738, saving model to best_model.keras
# Epoch 31: Validation Metrics: {'val_accuracy': 0.918410062789917, 'val_loss': 0.19737856090068817}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9251 - loss: 0.2049 - val_accuracy: 0.9184 - val_loss: 0.1974 - learning_rate: 1.0000e-04
# Epoch 32/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9209 - loss: 0.2061
# Epoch 32: val_loss improved from 0.19738 to 0.19276, saving model to best_model.keras
# Epoch 32: Validation Metrics: {'val_accuracy': 0.9246861934661865, 'val_loss': 0.19276373088359833}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9209 - loss: 0.2061 - val_accuracy: 0.9247 - val_loss: 0.1928 - learning_rate: 1.0000e-04
# Epoch 33/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9206 - loss: 0.2143
# Epoch 33: val_loss improved from 0.19276 to 0.19000, saving model to best_model.keras
# Epoch 33: Validation Metrics: {'val_accuracy': 0.926778256893158, 'val_loss': 0.1899951696395874}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9206 - loss: 0.2143 - val_accuracy: 0.9268 - val_loss: 0.1900 - learning_rate: 1.0000e-04
# Epoch 34/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9278 - loss: 0.2030
# Epoch 34: val_loss did not improve from 0.19000
# Epoch 34: Validation Metrics: {'val_accuracy': 0.9246861934661865, 'val_loss': 0.19082093238830566}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9278 - loss: 0.2030 - val_accuracy: 0.9247 - val_loss: 0.1908 - learning_rate: 1.0000e-04
# Epoch 35/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9283 - loss: 0.2012
# Epoch 35: val_loss did not improve from 0.19000
# Epoch 35: Validation Metrics: {'val_accuracy': 0.9205020666122437, 'val_loss': 0.19101153314113617}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9283 - loss: 0.2012 - val_accuracy: 0.9205 - val_loss: 0.1910 - learning_rate: 1.0000e-04
# Epoch 36/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9288 - loss: 0.1979
# Epoch 36: val_loss improved from 0.19000 to 0.18946, saving model to best_model.keras
# Epoch 36: Validation Metrics: {'val_accuracy': 0.926778256893158, 'val_loss': 0.18945994973182678}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9288 - loss: 0.1979 - val_accuracy: 0.9268 - val_loss: 0.1895 - learning_rate: 1.0000e-04
# Epoch 37/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9251 - loss: 0.1990
# Epoch 37: val_loss improved from 0.18946 to 0.18474, saving model to best_model.keras
# Epoch 37: Validation Metrics: {'val_accuracy': 0.9225941300392151, 'val_loss': 0.18473893404006958}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9251 - loss: 0.1990 - val_accuracy: 0.9226 - val_loss: 0.1847 - learning_rate: 1.0000e-04
# Epoch 38/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9298 - loss: 0.1917
# Epoch 38: val_loss improved from 0.18474 to 0.17895, saving model to best_model.keras
# Epoch 38: Validation Metrics: {'val_accuracy': 0.9330543875694275, 'val_loss': 0.17894825339317322}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9298 - loss: 0.1917 - val_accuracy: 0.9331 - val_loss: 0.1789 - learning_rate: 1.0000e-04
# Epoch 39/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9318 - loss: 0.1906
# Epoch 39: val_loss improved from 0.17895 to 0.17721, saving model to best_model.keras
# Epoch 39: Validation Metrics: {'val_accuracy': 0.9330543875694275, 'val_loss': 0.17720898985862732}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9318 - loss: 0.1906 - val_accuracy: 0.9331 - val_loss: 0.1772 - learning_rate: 1.0000e-04
# Epoch 40/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9344 - loss: 0.1875
# Epoch 40: val_loss did not improve from 0.17721
# Epoch 40: Validation Metrics: {'val_accuracy': 0.9330543875694275, 'val_loss': 0.17854496836662292}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9344 - loss: 0.1875 - val_accuracy: 0.9331 - val_loss: 0.1785 - learning_rate: 1.0000e-04
# Epoch 41/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9337 - loss: 0.1864
# Epoch 41: val_loss improved from 0.17721 to 0.17620, saving model to best_model.keras
# Epoch 41: Validation Metrics: {'val_accuracy': 0.939330518245697, 'val_loss': 0.17619574069976807}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9337 - loss: 0.1864 - val_accuracy: 0.9393 - val_loss: 0.1762 - learning_rate: 1.0000e-04
# Epoch 42/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9365 - loss: 0.1851
# Epoch 42: val_loss improved from 0.17620 to 0.17292, saving model to best_model.keras
# Epoch 42: Validation Metrics: {'val_accuracy': 0.9414225816726685, 'val_loss': 0.17291922867298126}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9365 - loss: 0.1851 - val_accuracy: 0.9414 - val_loss: 0.1729 - learning_rate: 1.0000e-04
# Epoch 43/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9319 - loss: 0.1810
# Epoch 43: val_loss improved from 0.17292 to 0.16787, saving model to best_model.keras
# Epoch 43: Validation Metrics: {'val_accuracy': 0.939330518245697, 'val_loss': 0.1678716093301773}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9319 - loss: 0.1810 - val_accuracy: 0.9393 - val_loss: 0.1679 - learning_rate: 1.0000e-04
# Epoch 44/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9346 - loss: 0.1838
# Epoch 44: val_loss improved from 0.16787 to 0.16448, saving model to best_model.keras
# Epoch 44: Validation Metrics: {'val_accuracy': 0.939330518245697, 'val_loss': 0.1644783914089203}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9347 - loss: 0.1838 - val_accuracy: 0.9393 - val_loss: 0.1645 - learning_rate: 1.0000e-04
# Epoch 45/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9381 - loss: 0.1785
# Epoch 45: val_loss did not improve from 0.16448
# Epoch 45: Validation Metrics: {'val_accuracy': 0.939330518245697, 'val_loss': 0.1691654771566391}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 44ms/step - accuracy: 0.9381 - loss: 0.1785 - val_accuracy: 0.9393 - val_loss: 0.1692 - learning_rate: 1.0000e-04
# Epoch 46/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9393 - loss: 0.1784
# Epoch 46: val_loss did not improve from 0.16448
# Epoch 46: Validation Metrics: {'val_accuracy': 0.9414225816726685, 'val_loss': 0.16668283939361572}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 44ms/step - accuracy: 0.9393 - loss: 0.1784 - val_accuracy: 0.9414 - val_loss: 0.1667 - learning_rate: 1.0000e-04
# Epoch 47/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9313 - loss: 0.1820
# Epoch 47: val_loss improved from 0.16448 to 0.16358, saving model to best_model.keras
# Epoch 47: Validation Metrics: {'val_accuracy': 0.9351464509963989, 'val_loss': 0.1635764092206955}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9313 - loss: 0.1820 - val_accuracy: 0.9351 - val_loss: 0.1636 - learning_rate: 1.0000e-04
# Epoch 48/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9316 - loss: 0.1771
# Epoch 48: val_loss improved from 0.16358 to 0.16138, saving model to best_model.keras
# Epoch 48: Validation Metrics: {'val_accuracy': 0.9372385144233704, 'val_loss': 0.16137950122356415}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9316 - loss: 0.1771 - val_accuracy: 0.9372 - val_loss: 0.1614 - learning_rate: 1.0000e-04
# Epoch 49/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9306 - loss: 0.1798
# Epoch 49: val_loss improved from 0.16138 to 0.15554, saving model to best_model.keras
# Epoch 49: Validation Metrics: {'val_accuracy': 0.9414225816726685, 'val_loss': 0.1555434763431549}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9306 - loss: 0.1797 - val_accuracy: 0.9414 - val_loss: 0.1555 - learning_rate: 1.0000e-04
# Epoch 50/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9363 - loss: 0.1733
# Epoch 50: val_loss did not improve from 0.15554
# Epoch 50: Validation Metrics: {'val_accuracy': 0.9372385144233704, 'val_loss': 0.15745195746421814}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9363 - loss: 0.1733 - val_accuracy: 0.9372 - val_loss: 0.1575 - learning_rate: 1.0000e-04
# Epoch 51/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9430 - loss: 0.1687
# Epoch 51: val_loss did not improve from 0.15554
# Epoch 51: Validation Metrics: {'val_accuracy': 0.9414225816726685, 'val_loss': 0.1560240536928177}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9430 - loss: 0.1687 - val_accuracy: 0.9414 - val_loss: 0.1560 - learning_rate: 1.0000e-04
# Epoch 52/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9392 - loss: 0.1694
# Epoch 52: val_loss did not improve from 0.15554
# Epoch 52: Validation Metrics: {'val_accuracy': 0.9330543875694275, 'val_loss': 0.15747292339801788}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9392 - loss: 0.1694 - val_accuracy: 0.9331 - val_loss: 0.1575 - learning_rate: 1.0000e-04
# Epoch 53/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9388 - loss: 0.1684
# Epoch 53: val_loss improved from 0.15554 to 0.14820, saving model to best_model.keras
# Epoch 53: Validation Metrics: {'val_accuracy': 0.9456067085266113, 'val_loss': 0.1482023447751999}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9388 - loss: 0.1684 - val_accuracy: 0.9456 - val_loss: 0.1482 - learning_rate: 1.0000e-04
# Epoch 54/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9404 - loss: 0.1654
# Epoch 54: val_loss improved from 0.14820 to 0.14799, saving model to best_model.keras
# Epoch 54: Validation Metrics: {'val_accuracy': 0.9435146450996399, 'val_loss': 0.14799000322818756}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9404 - loss: 0.1654 - val_accuracy: 0.9435 - val_loss: 0.1480 - learning_rate: 1.0000e-04
# Epoch 55/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9433 - loss: 0.1621
# Epoch 55: val_loss did not improve from 0.14799
# Epoch 55: Validation Metrics: {'val_accuracy': 0.9435146450996399, 'val_loss': 0.15001697838306427}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9433 - loss: 0.1621 - val_accuracy: 0.9435 - val_loss: 0.1500 - learning_rate: 1.0000e-04
# Epoch 56/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9408 - loss: 0.1640
# Epoch 56: val_loss did not improve from 0.14799
# Epoch 56: Validation Metrics: {'val_accuracy': 0.9456067085266113, 'val_loss': 0.14879631996154785}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9408 - loss: 0.1640 - val_accuracy: 0.9456 - val_loss: 0.1488 - learning_rate: 1.0000e-04
# Epoch 57/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9424 - loss: 0.1618
# Epoch 57: val_loss improved from 0.14799 to 0.14289, saving model to best_model.keras
# Epoch 57: Validation Metrics: {'val_accuracy': 0.9476987719535828, 'val_loss': 0.14288972318172455}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9424 - loss: 0.1618 - val_accuracy: 0.9477 - val_loss: 0.1429 - learning_rate: 1.0000e-04
# Epoch 58/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9444 - loss: 0.1660
# Epoch 58: val_loss improved from 0.14289 to 0.14026, saving model to best_model.keras
# Epoch 58: Validation Metrics: {'val_accuracy': 0.9476987719535828, 'val_loss': 0.1402643471956253}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9444 - loss: 0.1660 - val_accuracy: 0.9477 - val_loss: 0.1403 - learning_rate: 1.0000e-04
# Epoch 59/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9421 - loss: 0.1648
# Epoch 59: val_loss did not improve from 0.14026
# Epoch 59: Validation Metrics: {'val_accuracy': 0.9456067085266113, 'val_loss': 0.14435268938541412}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9421 - loss: 0.1648 - val_accuracy: 0.9456 - val_loss: 0.1444 - learning_rate: 1.0000e-04
# Epoch 60/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9369 - loss: 0.1643
# Epoch 60: val_loss did not improve from 0.14026
# Epoch 60: Validation Metrics: {'val_accuracy': 0.9476987719535828, 'val_loss': 0.14110559225082397}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9370 - loss: 0.1643 - val_accuracy: 0.9477 - val_loss: 0.1411 - learning_rate: 1.0000e-04
# Epoch 61/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9468 - loss: 0.1588
# Epoch 61: val_loss did not improve from 0.14026
# Epoch 61: Validation Metrics: {'val_accuracy': 0.9456067085266113, 'val_loss': 0.1435583382844925}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9468 - loss: 0.1588 - val_accuracy: 0.9456 - val_loss: 0.1436 - learning_rate: 1.0000e-04
# Epoch 62/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9405 - loss: 0.1609
# Epoch 62: val_loss did not improve from 0.14026
# Epoch 62: Validation Metrics: {'val_accuracy': 0.9458333253860474, 'val_loss': 0.14210540056228638}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9405 - loss: 0.1609 - val_accuracy: 0.9458 - val_loss: 0.1421 - learning_rate: 1.0000e-04
# Epoch 63/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9446 - loss: 0.1574
# Epoch 63: val_loss did not improve from 0.14026
# Epoch 63: Validation Metrics: {'val_accuracy': 0.9497907757759094, 'val_loss': 0.14048324525356293}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9446 - loss: 0.1573 - val_accuracy: 0.9498 - val_loss: 0.1405 - learning_rate: 1.0000e-04
# Epoch 64/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9444 - loss: 0.1539
# Epoch 64: val_loss improved from 0.14026 to 0.13584, saving model to best_model.keras
# Epoch 64: Validation Metrics: {'val_accuracy': 0.9518828392028809, 'val_loss': 0.13584056496620178}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9444 - loss: 0.1539 - val_accuracy: 0.9519 - val_loss: 0.1358 - learning_rate: 5.0000e-05
# Epoch 65/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9472 - loss: 0.1482
# Epoch 65: val_loss did not improve from 0.13584
# Epoch 65: Validation Metrics: {'val_accuracy': 0.9518828392028809, 'val_loss': 0.1396811157464981}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9472 - loss: 0.1482 - val_accuracy: 0.9519 - val_loss: 0.1397 - learning_rate: 5.0000e-05
# Epoch 66/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9470 - loss: 0.1498
# Epoch 66: val_loss did not improve from 0.13584
# Epoch 66: Validation Metrics: {'val_accuracy': 0.9539749026298523, 'val_loss': 0.13705115020275116}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9470 - loss: 0.1498 - val_accuracy: 0.9540 - val_loss: 0.1371 - learning_rate: 5.0000e-05
# Epoch 67/150
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9500 - loss: 0.1462
# Epoch 67: val_loss did not improve from 0.13584
# Epoch 67: Validation Metrics: {'val_accuracy': 0.9518828392028809, 'val_loss': 0.13821706175804138}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9500 - loss: 0.1462 - val_accuracy: 0.9519 - val_loss: 0.1382 - learning_rate: 5.0000e-05
# Epoch 68/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9457 - loss: 0.1481
# Epoch 68: val_loss did not improve from 0.13584
# Epoch 68: Validation Metrics: {'val_accuracy': 0.9518828392028809, 'val_loss': 0.13838718831539154}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9457 - loss: 0.1481 - val_accuracy: 0.9519 - val_loss: 0.1384 - learning_rate: 5.0000e-05
# Epoch 69/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9481 - loss: 0.1492
# Epoch 69: val_loss did not improve from 0.13584
# Epoch 69: Validation Metrics: {'val_accuracy': 0.9476987719535828, 'val_loss': 0.13891641795635223}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9481 - loss: 0.1492 - val_accuracy: 0.9477 - val_loss: 0.1389 - learning_rate: 5.0000e-05
# Epoch 70/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9466 - loss: 0.1528
# Epoch 70: val_loss did not improve from 0.13584
# Epoch 70: Validation Metrics: {'val_accuracy': 0.9476987719535828, 'val_loss': 0.13947899639606476}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9466 - loss: 0.1528 - val_accuracy: 0.9477 - val_loss: 0.1395 - learning_rate: 2.5000e-05
# Epoch 71/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9524 - loss: 0.1481
# Epoch 71: val_loss did not improve from 0.13584
# Epoch 71: Validation Metrics: {'val_accuracy': 0.9435146450996399, 'val_loss': 0.14024147391319275}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9524 - loss: 0.1480 - val_accuracy: 0.9435 - val_loss: 0.1402 - learning_rate: 2.5000e-05
# Epoch 72/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9532 - loss: 0.1445
# Epoch 72: val_loss did not improve from 0.13584
# Epoch 72: Validation Metrics: {'val_accuracy': 0.9497907757759094, 'val_loss': 0.1391720175743103}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9532 - loss: 0.1445 - val_accuracy: 0.9498 - val_loss: 0.1392 - learning_rate: 2.5000e-05
# Epoch 73/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9490 - loss: 0.1479
# Epoch 73: val_loss did not improve from 0.13584
# Epoch 73: Validation Metrics: {'val_accuracy': 0.9497907757759094, 'val_loss': 0.13720360398292542}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9490 - loss: 0.1479 - val_accuracy: 0.9498 - val_loss: 0.1372 - learning_rate: 2.5000e-05
# Epoch 74/150
# 485/486 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9541 - loss: 0.1422
# Epoch 74: val_loss did not improve from 0.13584
# Epoch 74: Validation Metrics: {'val_accuracy': 0.9497907757759094, 'val_loss': 0.13798676431179047}
# 486/486 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9540 - loss: 0.1422 - val_accuracy: 0.9498 - val_loss: 0.1380 - learning_rate: 2.5000e-05
# Total training time: 1660.99 seconds

# %% [markdown]
# # **Visualisasi Hasil Pelatihan**

# %%
# Membuat plot dengan ukuran 12x4 inch
plt.figure(figsize=(12, 4))

# Tampilkan akurasi pelatihan dan validasi
plt.subplot(1, 2, 1)  
plt.plot(history.history['accuracy'], label='Akurasi Pelatihan')  
plt.plot(history.history['val_accuracy'], label='Akurasi Validasi') 
plt.xlabel('Epoch')  
plt.ylabel('Akurasi')  
plt.title('Akurasi Pelatihan dan Validasi')  
plt.legend()  
plt.grid()  

# Tampilkan loss pelatihan dan validasi
plt.subplot(1, 2, 2)  
plt.plot(history.history['loss'], label='Loss Pelatihan')  
plt.plot(history.history['val_loss'], label='Loss Validasi')  
plt.xlabel('Epoch')  
plt.ylabel('Loss')  
plt.title('Loss Pelatihan dan Validasi')  
plt.legend()  
plt.grid()  

# Mengatur layout plot agar tidak overlap
plt.tight_layout()

# Menampilkan plot
plt.show()

# %% [markdown]
# # **Evaluasi Model dari Set Pengujian**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# Inisialisasi data untuk evaluasi
test_data_generator = data_generator(df_test, batch_size=cfg.BATCH_SIZE, augment=False, epochs=1)

# Inisialisasi prediksi dan label yang sesungguhnya
results = []  # Untuk menyimpan hasil evaluasi per sampel

# Inisialisasi nilai loss
loss = 0
count = 0

# Loop untuk mendapatkan prediksi dan label sesungguhnya
while True:
    try:
        x, y = next(test_data_generator)
        filenames = df_test.path[len(results):len(results) + len(y)]  # Ambil nama file batch
        
        # Prediksi probabilitas dan kelas
        preds = model.predict(x)
        pred_classes = np.argmax(preds, axis=-1)
        
        # Jika y adalah one-hot encoded
        if len(y.shape) > 1 and y.shape[-1] > 1:
            y = np.argmax(y, axis=-1)

        # Simpan hasil evaluasi
        for i, file_name in enumerate(filenames):
            result = {
                "filename": file_name,
                "true": int(y[i]),
                "predicted": int(pred_classes[i]),
                "probabilities": preds[i].tolist()
            }
            results.append(result)
        
        # Hitung nilai loss
        # Hitung nilai loss
        loss += model.evaluate(x, y, verbose=0)[0]
        count += 1
    except StopIteration:
        break

# Hitung nilai loss rata-rata
loss /= count
print(f'Test Loss: {loss:.4f}')

# Simpan hasil dalam CSV
df_results = pd.DataFrame(results)
df_results.to_csv("evaluation_results.csv", index=False)

# Tampilkan classification report
y_true = [r["true"] for r in results]
y_pred = [r["predicted"] for r in results]
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=LABELS, digits=4))

# Visualisasi confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=LABELS, yticklabels=LABELS)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Test Loss: 0.1721
# Classification Report:
#               precision    recall  f1-score   support
#
#       NORMAL     0.9742    0.9437    0.9587       160
# TUBERCULOSIS     0.8696    0.9375    0.9023        64
#    PNEUMONIA     0.9524    0.9709    0.9615       206
#      COVID19     0.8889    0.8276    0.8571        58
#
#     accuracy                         0.9406       488
#    macro avg     0.9213    0.9199    0.9199       488
# weighted avg     0.9411    0.9406    0.9404       488

# %%
accuracy = np.sum(np.diag(cm)) / np.sum(cm)
print(f"Nilai Akurasi Pengujian: {accuracy:.4%}")
# Out:
# Nilai Akurasi Pengujian: 94.0574%

# %%
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2%', cmap='Blues', xticklabels=LABELS, yticklabels=LABELS)
plt.title("Normalized Confusion Matrix")
plt.show()

# %% [markdown]
# # **Menyimpan Model**

# %%
# Save the final model after training
model_path = '/kaggle/working/skripsi_model_CNN.h5'
model.save(model_path)

# %% [markdown]
# # **Pengujian Model Menggunakan Notebook**

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import load_img

def predict(image, model):
    model_path = '/kaggle/working/segmentation_model_final.keras'
    labels = ['NORMAL', 'TUBERCULOSIS', 'PNEUMONIA', 'COVID19']
    image = np.array(image)
    image = image / image.max()  # Normalisasi gambar
    image = image.reshape(-1, cfg.IMAGE_SIZE, cfg.IMAGE_SIZE, 3)  # Ubah bentuk
    probabilities = model.predict(image).reshape(-1)  # Prediksi probabilitas
    pred = labels[np.argmax(probabilities)]  # Kelas dengan probabilitas tertinggi
    return pred, {x: y for x, y in zip(labels, probabilities)}  # Kembalikan prediksi dan probabilitas

# Mengambil 7 indeks acak untuk pengujian
INDICES = random.sample(list(df.index), 7)

for INDEX in INDICES:
    # Muat gambar dan ubah ukurannya
    image = load_img(df.path[INDEX], target_size=(cfg.IMAGE_SIZE, cfg.IMAGE_SIZE))
    
    # Dapatkan prediksi dan probabilitas
    pred, probabilities = predict(image, model)

    # Ambil label dan nilai probabilitas
    x = list(probabilities.keys())
    y = list(probabilities.values())

    # Set tampilan untuk visualisasi
    sns.set_style("whitegrid")
    fig, ax = plt.subplots(1, 2, figsize=(18, 6), gridspec_kw={'width_ratios': [2, 3]})

    # Plot gambar
    ax[0].imshow(image)
    ax[0].axis('off')  # Matikan sumbu pada gambar
    ax[0].set_title(f'Predicted: {pred}', fontsize=14, color='darkblue', weight='bold')

    # Membuat bar chart untuk probabilitas kelas
    bars = ax[1].barh(x, y, height=0.5, color=sns.color_palette("pastel", len(x)))
    ax[1].bar_label(bars, fmt='%.2f', padding=5, fontsize=12, label_type='edge', color='black')

    ax[1].set_xlim(0, 1)
    ax[1].set_xticks(np.arange(0, 1.1, 0.1))
    ax[1].set_xlabel('Probability', fontsize=12)
    ax[1].set_title('Class Probabilities', fontsize=14, color='darkgreen', weight='bold')
    ax[1].tick_params(axis='y', labelsize=12)
    ax[1].tick_params(axis='x', labelsize=10)
    ax[1].grid(axis='x', linestyle='--', alpha=0.7)

    plt.tight_layout()
    plt.show()

    # Tampilkan hasil pengujian
    print(f"Actual Label   : {df.label[INDEX]}")
    print(f"Predicted Label: {pred}")
    print('-' * 80)
    print('\n')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Actual Label   : PNEUMONIA
# Predicted Label: PNEUMONIA
# --------------------------------------------------------------------------------
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Actual Label   : NORMAL
# Predicted Label: NORMAL
# --------------------------------------------------------------------------------
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Actual Label   : PNEUMONIA
# Predicted Label: PNEUMONIA
# --------------------------------------------------------------------------------
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Actual Label   : NORMAL
# Predicted Label: NORMAL
# --------------------------------------------------------------------------------
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Actual Label   : COVID19
# Predicted Label: COVID19
# --------------------------------------------------------------------------------
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Actual Label   : PNEUMONIA
# Predicted Label: PNEUMONIA
# --------------------------------------------------------------------------------
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Actual Label   : NORMAL
# Predicted Label: NORMAL
# --------------------------------------------------------------------------------

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Fungsi untuk memplot feature map terbaik dari tiap layer
def plot_best_feature_maps(model, image_path):
    # Load dan preprocess gambar
    image_input = load_img(image_path, target_size=(256, 256))
    image_input = img_to_array(image_input) / 255.0  # Normalisasi
    image_input = np.expand_dims(image_input, axis=0)  # Tambah batch dimension

    # Pilih layer Conv2D
    layer_outputs = [layer.output for layer in model.layers if 'conv' in layer.name]
    feature_map_model = Model(inputs=model.input, outputs=layer_outputs)

    # Dapatkan feature maps
    feature_maps = feature_map_model.predict(image_input)

    # Plot feature map terbaik dari tiap layer berdasarkan varians tertinggi
    fig, axes = plt.subplots(1, len(feature_maps), figsize=(15, 5))
    for fmap_idx, fmap in enumerate(feature_maps):
        # Hitung varians tiap channel
        variances = np.var(fmap[0], axis=(0, 1))
        best_channel = np.argmax(variances)

        # Plot feature map terbaik secara horizontal
        axes[fmap_idx].imshow(fmap[0, :, :, best_channel], cmap='viridis')
        axes[fmap_idx].set_title(f"Layer {fmap_idx + 1}")
        axes[fmap_idx].axis('off')

    plt.tight_layout()
    plt.show()

# Contoh pemanggilan fungsi
plot_best_feature_maps(model, '/kaggle/input/dataset-klasifikasi-v5/NORMAL/seg_IM-0001-0001.jpeg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-2138c48eca5e> in <cell line: 36>()
#      34
#      35 # Contoh pemanggilan fungsi
# ---> 36 plot_best_feature_maps(model, '/kaggle/input/dataset-klasifikasi-v5/NORMAL/seg_IM-0001-0001.jpeg')
#
# <ipython-input-29-2138c48eca5e> in plot_best_feature_maps(model, image_path)
#      13     # Pilih layer Conv2D
#      14     layer_outputs = [layer.output for layer in model.layers if 'conv' in layer.name]
# ---> 15     feature_map_model = Model(inputs=model.input, outputs=layer_outputs)
#      16
#      17     # Dapatkan feature maps
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/tracking.py in wrapper(*args, **kwargs)
#      24     def wrapper(*args, **kwargs):
#      25         with DotNotTrackScope():
# ---> 26             return fn(*args, **kwargs)
#      27
#      28     return wrapper
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/functional.py in __init__(self, inputs, outputs, name, **kwargs)
#     133             inputs, outputs = clone_graph_nodes(inputs, outputs)
#     134
# --> 135         Function.__init__(self, inputs, outputs, name=name, **kwargs)
#     136
#     137         if trainable is not None:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/function.py in __init__(self, inputs, outputs, name)
#      66             )
#      67         if not self._outputs:
# ---> 68             raise ValueError(
#      69                 "`outputs` argument cannot be empty. Received:\n"
#      70                 f"inputs={inputs}\n"
#
# ValueError: `outputs` argument cannot be empty. Received:
# inputs=<KerasTensor shape=(None, 256, 256, 3), dtype=float32, sparse=False, name=keras_tensor_23>
# outputs=[]

# %%
# Contoh pemanggilan fungsi
plot_best_feature_maps(model, '/kaggle/input/dataset-klasifikasi-v5/COVID19/seg_COVID19(1).jpg')

# %%
plot_best_feature_maps(model, '/kaggle/input/dataset-klasifikasi-v5/PNEUMONIA/seg_person1000_bacteria_2931.jpeg')

# %%
plot_best_feature_maps(model, '/kaggle/input/dataset-klasifikasi-v5/TUBERCULOSIS/seg_Tuberculosis-107.png')
